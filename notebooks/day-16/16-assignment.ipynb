# %% [markdown]
# # Day 16 Assignment — Data Flow Design

# %% [markdown]
# ## Tasks
# ### A1. Data Flow for sales fact.
# ### A2. SCD1 customer update steps.
# ### A3. Data Flow vs Spark for 500GB SCD pipeline.
# ### A4. Debugging bad joins.
# ### A5. Cost/performance talking points.

# %% [markdown]
# ### Answers
# ...
