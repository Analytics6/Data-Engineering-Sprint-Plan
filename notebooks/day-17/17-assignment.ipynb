# %% [markdown]
# # Day 17 Assignment — Secure Landing Zone

# %% [markdown]
# ## Tasks
# ### A1. Secure ADF setup inventory.
# ### B. Secrets in Key Vault vs non-secrets.
# ### C. Three SHIR-mandatory examples.
# ### D. Private endpoint explanation.
# ### E. Security anti-patterns.

# %%
import pandas as pd
# A1

# %% [markdown]
# ### B-E
# ...
