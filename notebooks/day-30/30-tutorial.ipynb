# %% [markdown]
# # Day 30 Tutorial — Final Interview Day Prep
#
# ## Mocks
# - Mock A: PySpark + SQL
# - Mock B: ADF + Fabric
#
# ## STAR stories
# 1. Performance win
# 2. Incident/failure
# 3. Tool-choice trade-off
#
# ## Intro template
# I'm a data engineer focused on Azure analytics. I build ingestion/transform pipelines with SQL/PySpark, orchestrate with ADF/Fabric, and model data with medallion + star schema patterns. Recently I ...

# %% [markdown]
# ### Environment setup
# Skip pip install on Databricks/Fabric. Locally you may need: `pip install pyspark pandas`.

# %%
# %pip install pyspark==3.5.1 pandas -q

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import types as T
from pyspark.sql.window import Window

spark = (
    SparkSession.builder
    .appName('AzureDE-InterviewPrep')
    .master('local[*]')
    .config('spark.sql.shuffle.partitions', '4')
    .getOrCreate()
)
spark

# %%
data = spark.createDataFrame(
    [('a', 1, 10), ('a', 2, 5), ('b', 1, 7), ('b', 1, 7)],
    ['k', 'day', 'v'],
)
w = Window.partitionBy('k').orderBy(F.col('day').desc())
data.dropDuplicates(['k', 'day', 'v']).withColumn('rn', F.row_number().over(w)).filter('rn=1').show()
