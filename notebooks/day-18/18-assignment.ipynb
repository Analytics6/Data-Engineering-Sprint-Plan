# %% [markdown]
# # Day 18 Assignment — Ops Readiness

# %% [markdown]
# ## Tasks
# ### A1. Recovery runbook for partial copy failure.
# ### A2. Retry policy defaults.
# ### A3. CI/CD promotion sketch.
# ### A4. Three alerting rules.
# ### A5. Idempotent daily sales design.

# %% [markdown]
# ### Answers
# ...
