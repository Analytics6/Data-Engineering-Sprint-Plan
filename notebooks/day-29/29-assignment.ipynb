# %% [markdown]
# # Day 29 Assignment — 40-Question Blitz + Top 20 Sheet
#
# Write short answers; then compress into a Top 20 cheat sheet.

# %% [markdown]
# ## Architecture (10)
# Medallion, star schema, SCD1/2, idempotent load, watermark, OneLake, Lakehouse vs Warehouse, SHIR, bronze vs gold quality, batch vs streaming
#
# ## Coding (10)
# Latest dedupe, broadcast join, anti join, running total, MERGE, LAG MoM, top N, explode JSON, repartition vs coalesce, fact grain
#
# ## Scenarios (10)
# Late files, skew, ForEach partial fail, schema drift, cost spike, duplicate facts, CDC vs watermark, Fabric migration, Key Vault, restart after partial load
#
# ## Behavioral (10)
# Intro, hardest pipeline, conflict, mistake, perf win, mentoring, priorities, stakeholder comms, learning plan, questions for interviewer

# %% [markdown]
# ### Your answers
# ...
#
# ### Top 20 cheat sheet
# ...
